# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Reading the file
df = pd.read_csv("Datasets/pima-indians-diabetes.csv")
df
# Out:
#      pregs  plas  pres  skin  test   BMI   pedi  Age  class
# 0        6   148    72    35     0  33.6  0.627   50      1
# 1        1    85    66    29     0  26.6  0.351   31      0
# 2        8   183    64     0     0  23.3  0.672   32      1
# 3        1    89    66    23    94  28.1  0.167   21      0
# 4        0   137    40    35   168  43.1  2.288   33      1
# ..     ...   ...   ...   ...   ...   ...    ...  ...    ...
# 763     10   101    76    48   180  32.9  0.171   63      0
# 764      2   122    70    27     0  36.8  0.340   27      0
# 765      5   121    72    23   112  26.2  0.245   30      0
# 766      1   126    60     0     0  30.1  0.349   47      1
# 767      1    93    70    31     0  30.4  0.315   23      0
#
# [768 rows x 9 columns]

# %%
# 1. Display the first 10 tuples of the given dataset using the ‘head()‘ function.

df.head(10)
# Out:
#    pregs  plas  pres  skin  test   BMI   pedi  Age  class
# 0      6   148    72    35     0  33.6  0.627   50      1
# 1      1    85    66    29     0  26.6  0.351   31      0
# 2      8   183    64     0     0  23.3  0.672   32      1
# 3      1    89    66    23    94  28.1  0.167   21      0
# 4      0   137    40    35   168  43.1  2.288   33      1
# 5      5   116    74     0     0  25.6  0.201   30      0
# 6      3    78    50    32    88  31.0  0.248   26      1
# 7     10   115     0     0     0  35.3  0.134   29      0
# 8      2   197    70    45   543  30.5  0.158   53      1
# 9      8   125    96     0     0   0.0  0.232   54      1

# %%
# 2. Display the structure of the data to provide details about the number of 
#entries, data types, and memory usage of the dataset using the ‘info()‘function.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   pregs   768 non-null    int64
#  1   plas    768 non-null    int64
#  2   pres    768 non-null    int64
#  3   skin    768 non-null    int64
#  4   test    768 non-null    int64
#  5   BMI     768 non-null    float64
#  6   pedi    768 non-null    float64
#  7   Age     768 non-null    int64
#  8   class   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
# 3. Generate the descriptive statistics for each numerical attribute using
# the ‘describe()‘ function to provide the count, mean, standard devia-
# tion, minimum, 25th percentile (Q1), median (50th percentile or Q2),
# 75th percentile (Q3), and maximum of the columns.

df.describe()
# Out:
#             pregs        plas        pres        skin        test         BMI  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     3.845052  120.894531   69.105469   20.536458   79.799479   31.992578
# std      3.369578   31.972618   19.355807   15.952218  115.244002    7.884160
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   30.500000   32.000000
# 75%      6.000000  140.250000   80.000000   32.000000  127.250000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#              pedi         Age       class
# count  768.000000  768.000000  768.000000
# mean     0.471876   33.240885    0.348958
# std      0.331329   11.760232    0.476951
# min      0.078000   21.000000    0.000000
# 25%      0.243750   24.000000    0.000000
# 50%      0.372500   29.000000    0.000000
# 75%      0.626250   41.000000    1.000000
# max      2.420000   81.000000    1.000000

# %%
# 4. Calculate and display the following statistical measures for each at-
# tribute using the respective functions: mean using ‘mean()‘, median
# using ‘median()‘, mode using ‘mode()‘, minimum using ‘min()‘, maxi-
# mum using ‘max()‘, and standard deviation using ‘std()‘. Additionally,
# compute the quartiles (Q1, Q2, and Q3) using ‘quantile()‘ and the
# Interquartile Range (IQR) by subtracting Q1 from Q3.

for i in df.columns:
    print("---", i, "---")    
    mean = df[i].mean()
    print("Mean: ", mean)

    median = df[i].median()
    print("Median: ", median)

    mode = df[i].mode()[0]
    print("Mode: ", mode)

    mini = df[i].min()
    print("Min: ", mini)

    maxi = df[i].max()
    print("Max: ", maxi)

    std = df[i].std()
    print("Std. Deviation: ", std)

    Q1 = df[i].quantile(0.25)
    print("1st Quartile: ", Q1)

    Q2 = df[i].quantile(0.50)
    print("2nd Quartile: ", Q2)

    Q3 = df[i].quantile(0.75)
    print("3rd Quartile: ", Q3)

    IQR = Q3-Q1
    print("IQR: ", IQR)
# Out:
# --- pregs ---
# Mean:  3.8450520833333335
# Median:  3.0
# Mode:  1
# Min:  0
# Max:  17
# Std. Deviation:  3.3695780626988694
# 1st Quartile:  1.0
# 2nd Quartile:  3.0
# 3rd Quartile:  6.0
# IQR:  5.0
# --- plas ---
# Mean:  120.89453125
# Median:  117.0
# Mode:  99
# Min:  0
# Max:  199
# Std. Deviation:  31.97261819513622
# 1st Quartile:  99.0
# 2nd Quartile:  117.0
# 3rd Quartile:  140.25
# IQR:  41.25
# --- pres ---
# Mean:  69.10546875
# Median:  72.0
# Mode:  70
# Min:  0
# Max:  122
# Std. Deviation:  19.355807170644777
# 1st Quartile:  62.0
# 2nd Quartile:  72.0
# 3rd Quartile:  80.0
# IQR:  18.0
# --- skin ---
# Mean:  20.536458333333332
# Median:  23.0
# Mode:  0
# Min:  0
# Max:  99
# Std. Deviation:  15.952217567727637
# 1st Quartile:  0.0
# 2nd Quartile:  23.0
# 3rd Quartile:  32.0
# IQR:  32.0
# --- test ---
# Mean:  79.79947916666667
# Median:  30.5
# Mode:  0
# Min:  0
# Max:  846
# Std. Deviation:  115.24400235133817
# 1st Quartile:  0.0
# 2nd Quartile:  30.5
# 3rd Quartile:  127.25
# IQR:  127.25
# --- BMI ---
# Mean:  31.992578124999998
# Median:  32.0
# Mode:  32.0
# Min:  0.0
# Max:  67.1
# Std. Deviation:  7.884160320375446
# 1st Quartile:  27.3
# 2nd Quartile:  32.0
# 3rd Quartile:  36.6
# IQR:  9.3
# --- pedi ---
# Mean:  0.47187630208333325
# Median:  0.3725
# Mode:  0.254
# Min:  0.078
# Max:  2.42
# Std. Deviation:  0.3313285950127749
# 1st Quartile:  0.24375
# 2nd Quartile:  0.3725
# 3rd Quartile:  0.62625
# IQR:  0.38249999999999995
# --- Age ---
# Mean:  33.240885416666664
# Median:  29.0
# Mode:  22
# Min:  21
# Max:  81
# Std. Deviation:  11.760231540678685
# 1st Quartile:  24.0
# 2nd Quartile:  29.0
# 3rd Quartile:  41.0
# IQR:  17.0
# --- class ---
# Mean:  0.3489583333333333
# Median:  0.0
# Mode:  0
# Min:  0
# Max:  1
# Std. Deviation:  0.47695137724279896
# 1st Quartile:  0.0
# 2nd Quartile:  0.0
# 3rd Quartile:  1.0
# IQR:  1.0

# %%
# 5. Generate scatter plots to explore the relationships between skin, Age,
# BMI, pregs, and plas.

df2 = df[["skin", "Age", "BMI", "pregs", "plas"]]

for i in df2.columns:
    for j in df2.columns:
        if (i != j):
            sns.scatterplot(x=i,y=j, data=df2)
            plt.show()

# %%
# 6. Plot histograms for all numerical attributes and the kernel density es-
# timation (KDE) curve.

for i in df.columns:
    sns.histplot(x=i,bins=10, kde=True, data=df)
    plt.title('Count v/s Column')
    plt.show()

# %%
# 7. Group the data according to the attribute ‘class‘ and bar plots to an-
# alyze the distribution of the attributes ‘BMI‘, ‘Age‘, ‘plas‘, and ‘pres‘
# for each value of the ‘class‘ variable using the ‘groupby()‘ function.

df3 = df[["BMI", "Age", "plas", "pres"]]
df4= df.groupby('class')[["BMI", "Age", "plas", "pres"]].mean()
df4.plot(kind='bar')
plt.ylabel(i + "'s Mean")
plt.show()

df4= df.groupby('class')[["BMI", "Age", "plas", "pres"]].median()
df4.plot(kind='bar')
plt.ylabel(i + "'s Median")
plt.show()

for i in df3.columns:
    df4= df.groupby('class')[i].mean()
    df4.plot(kind='bar')
    plt.ylabel(i + "'s Mean")
    plt.show()

    df4= df.groupby('class')[i].median()
    df4.plot(kind='bar')
    plt.ylabel(i + "'s Median")
    plt.show()

# %%
# 8. Create boxplots for all attributes to identify outliers and compare dis-
# tributions.

for i in df.columns:
    sns.boxplot(x=i, data=df)
    plt.show()
